# %% [markdown]
# <a href="https://colab.research.google.com/github/clangreformers/clangreformers.github.io/blob/master/translate_tw_to_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install openai
# %pip install tiktoken
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.59.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Collecting tiktoken
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken) (2024.12.14)
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 14.2 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.8.0

# %%
from openai import OpenAI
import os
import tiktoken
from google.colab import userdata

OPENAI_API_KEY = userdata.get('openai_api_key')
# Set the API key as an environment variable
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# Directory containing files to translate
input_directory = "drive/MyDrive/clangreformers/PeterWang/tw"
output_directory = "drive/MyDrive/clangreformers/PeterWang/en"

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Function to count tokens
def count_tokens(text, model="gpt-4o-mini"):
    """Calculate the number of tokens in a given text for the specified model."""
    encoding = tiktoken.get_encoding("gpt2")
    return len(encoding.encode(text))

# Function to split text into manageable chunks
def split_text(text, max_tokens, model="gpt-4o-mini"):
    """Split text into chunks that fit within the token limit."""
    encoding = tiktoken.get_encoding("gpt2")
    tokens = encoding.encode(text)
    chunks = []
    for i in range(0, len(tokens), max_tokens):
        chunk = tokens[i:i + max_tokens]
        chunks.append(encoding.decode(chunk))
    return chunks

# Function to translate text using OpenAI o1mini API
def translate_text(text, source_lang="zh-TW", target_lang="en", model="gpt-4o-mini"):
    """Translate text using OpenAI o1mini API."""
    prompt = f"Translate the following text from {source_lang} to {target_lang}:\n\n{text}"
    try:
        response = client.chat.completions.create(
            model=model,
            messages=[
                {"role": "system", "content": "You are a helpful translation assistant."},
                {"role": "user", "content": prompt}
            ]
        )
        print(response)
        return response.choices[0].message.content.strip()
    except Exception as e:
        print(f"Error during translation: {e}")
        return None

# Token limit for the model
MODEL = "gpt-4o-mini"
MAX_TOKENS = 2000  # Adjust based on model's max context size
SAFE_LIMIT = MAX_TOKENS - 500  # Leave space for prompt and response

client = OpenAI()

# Iterate through all files in the input directory
for filename in os.listdir(input_directory):
    if filename.endswith(".txt"):  # Process only .txt files
        input_file_path = os.path.join(input_directory, filename)
        output_file_path = os.path.join(output_directory, filename)

        print(input_file_path)

        with open(input_file_path, "r", encoding="utf-8") as input_file:
            traditional_text = input_file.read()

        # Split text into manageable chunks if necessary
        if count_tokens(traditional_text, model=MODEL) > SAFE_LIMIT:
            text_chunks = split_text(traditional_text, SAFE_LIMIT, model=MODEL)
        else:
            text_chunks = [traditional_text]

        translated_text = ""

        # Translate each chunk
        for i, chunk in enumerate(text_chunks):
            print(f"Translating chunk {i + 1}/{len(text_chunks)} of {filename}...")
            result = translate_text(chunk, source_lang="Traditional Chinese", target_lang="English", model=MODEL)
            if result:
                translated_text += result + "\n"
            else:
                print(f"Failed to translate chunk {i + 1} of {filename}")

        # Save the translated text to the output file
        with open(output_file_path, "w", encoding="utf-8") as output_file:
            output_file.write(translated_text)

        print(f"Translated and saved: {filename}")

print("Translation completed.")
# Out:
# drive/MyDrive/clangreformers/PeterWang/tw/2024-12-21-profWangLostVoice-tw.txt
# Translating chunk 1/7 of 2024-12-21-profWangLostVoice-tw.txt...
# ChatCompletion(id='chatcmpl-AofDFVxmiv9ChbINhq7ZcooxIImSA', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content
refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1736638264, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_72ed7ab54c', usage=CompletionUsage(completion_tokens=646, prompt_tokens=721, total_tokens=1367, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Translating chunk 4/6 of 2024-12-09-mostBelovedUncleWang-tw.txt...
# ChatCompletion(id='chatcmpl-AofEeCSLHnPAHkFerTGSfRFmIOpZ8', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='After undergoing the baptism of two wars, my dad, who was still young at the time, was deeply pained to see the country weak, the people impoverished, backward, and ignorant, facing the brutal war like sheep waiting to be slaughtered. He believed that the prerequisite for a prosperous nation and a strong military was having citizens with modern knowledge. At that time, over ninety percent of the population in mainland China were illiterate, so implementing literacy education to eliminate illiteracy was the top priority. A modern nation must have a unified language to communicate effectively and work together in nation-building and resisting foreign aggression. Using phonetic symbols to guide and correct pronunciation was the first lesson in language education; promoting the national language was a lifelong work for him, and he hoped to see the entire country speaking the same language.\n\nMy father\'s pronunciation was pure and powerful, offering insights into the landscape and commenting on the world, recounting stories with humor and vividness; his everyday conversations were filled with clever remarks. His old friend Zhao Lede, who is the daughter of Uncle Zhao Youpei, recalled, "Back then, all of our siblings attended prestigious schools like the Normal University Affiliated High School and Taipei First Girls\' High School, and we were rather pretentious. When our parents\' friends visited, they mostly just fake-smiled and nodded, completely ignoring us. But when Uncle Wang came, we all rushed out to gather around and listen to him speak; he was so engaging that people of all ages enjoyed him."\n\nUncle Wang spoke with ease, humor, and a high level of mastery in the art of language. Uncle Zhao Youpei often invited my father over to the Zhao family for casual meals, saying, "There\'s nothing special to eat, just come over for a simple meal!" Uncle Wang corrected him, "The term \'simple meal\' should not be prefixed with \'simple\' or \'big.\'" Aunt Zhao kept serving dishes, urging everyone to eat, and Uncle Wang gestured to his neck, saying, "That\'s enough! I\'ve already eaten so much I\'m as thick as Duke Jing of Qi!"\n\nIn the sweltering summer, the robust Uncle Wang would carry a towel around, frequently wiping his face but still sweating profusely. One time he walked in, drenched in sweat, and said, "I truly am the ancient Hanlin (sweating) Duke!"\n\nIn the evenings, the Zhao family would relax in the yard, listening to Uncle Wang discuss past and present while surrounded by mosquitoes. Uncle Wang could not stand it anymore and exclaimed, "Let’s go inside! Otherwise, we’ll all become Wei Wendi (mosquito-food siblings)!" \n\nMy father gave a speech at the wedding of young editors Lin Liang from the National Language Daily and Zheng Xiuzhi: “The names of these two form the four characters ‘Xiulinliangzhi.’ From now on, not only...”', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1736638272, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_72ed7ab54c', usage=CompletionUsage(completion_tokens=591, prompt_tokens=705, total_tokens=1296, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Translating chunk 5/6 of 2024-12-09-mostBelovedUncleWang-tw.txt...
# ChatCompletion(id='chatcmpl-AofElxlnUWvEcmgb9IzGmvKUYoszZ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='"With perfect harmony and a guarantee of excellent offspring, this is a match made in heaven."\n\nWe came to Taiwan in 1948. My father was invited by the Taiwan Provincial Department of Education to serve as a member of the National Language Promotion Committee, where he started the Guoyu Daily in Taiwan. In addition to publishing the newspaper, he frequently went on the radio to teach Mandarin, alongside Uncle Lin, who was originally from Fujian and provided translations in Taiwanese. The Taipei City Bureau of Education invited him to establish a Mandarin learning class for elementary school teachers, to correct actors’ stage pronunciations at Taiwan Film Studio, and he founded a specialized Mandarin program at the Provincial Normal University, later also establishing a Mandarin center to teach foreign students Chinese, keeping him extremely busy every day.\n\nUncle Zhao Youpei praised his old friend\'s impressive speeches:\n\n"When he stepped onto the podium, his presence was imposing and his delivery was vivid, so compelling that one could not help but be drawn in. Yet, he was also able to explain complex ideas in simple terms, with sparkling wit that delighted the audience, who laughed heartily and applauded enthusiastically."\n\nI didn’t listen to many of my father’s speeches on language education, but I remember one time he used "The Flower-Tailed Dog" as a topic: "The flower-tailed dog is a dog, the flower dog tail is a part of a dog, and the dog tail flower is a flower." He constructed the following sentence: "The flower-tailed dog chased its own flower dog tail and bit down on a dog tail flower."\n\nThere were many such examples that illustrated the wonder of the Chinese language.\n\nWhen he gave a speech in Taitung, someone gifted my father a black wood cane, which he cherished greatly and even hugged it to sleep that night. He happily said:\n\n"In the future, I will use this cane to whack those confused individuals who are neither kind nor wise."\n\nUncle Zhao always praised my father as a steadfast and righteous man, open and straightforward, clear about public and private matters, tough despite being poor, increasingly tenacious in adversity, characterized by his masculine demeanor. When he was in high spirits, he would often swing his cane around or gesture emphatically.\n\nLanguage education was his strongest conviction. One of his students wanted to change careers, and my father told him:\n\n"Why not go to the market and sell vegetables? Just sell whatever is in season!"\n\nThat student remained devoted to his position in language education for his entire life.\n\nAnother student, who failed the national phonetics exam, passed on his second attempt and recalled:\n\n"If Teacher Wang had given out easy grades back then, I wouldn’t be able to speak such beautiful Mandarin today."\n\nLi Zida (the famous director Li Xing) attended my father’s national phonetics class at Normal University and believed his Mandarin was already quite standard, thinking he didn\'t need to attend class anymore.', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1736638279, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_72ed7ab54c', usage=CompletionUsage(completion_tokens=590, prompt_tokens=700, total_tokens=1290, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Translating chunk 6/6 of 2024-12-09-mostBelovedUncleWang-tw.txt...
# ChatCompletion(id='chatcmpl-AofEulmOziSlsDskgcJpmfcw21TNz', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='At the end of the semester, his father gave him sixty points; Director Li has never learned phonetic symbols.\n\nNow many people are praised as "famous commentators" or "national commentators." In my humble opinion, most of them are not qualified. I have only seen one true famous commentator in the world; my late father, known as Uncle Wang, is the one. The primary condition for being a famous commentator is to have a certain language spoken to a standard; no matter which language it is, if someone’s pronunciation is off and their tones are incorrect, the listener\'s understanding immediately suffers, and their ability to express ideas lacks the most basic skills, let alone anything else. Only then can we talk about eloquence, humor, and wit; a wealth of knowledge is needed to draw on various references, grasp the balance of urgency and importance, maintain coherence and logic, and hit the nail on the head, leaving the listener enlightened. The so-called famous commentators of today are, frankly speaking, not commendable at all; one cannot say, one cannot say!', refusal=None, role='assistant', audio=None, function_call=None, tool_calls=None))], created=1736638288, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_bd83329f63', usage=CompletionUsage(completion_tokens=217, prompt_tokens=251, total_tokens=468, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))
# Translated and saved: 2024-12-09-mostBelovedUncleWang-tw.txt
# Translation completed.

# %% [markdown]
# # New Section
